# %%
print("ok")
# Out:
# ok

# %%
import os

from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models are crucial in the field of natural language processing (NLP) as they enable efficient and effective processing of human language. The importance of fast language models can be understood from several perspectives:
#
# 1. **Real-time Applications**: Fast language models are essential for real-time applications, such as chatbots, virtual assistants, and voice-controlled devices. These models need to process and respond to user input quickly, often in a matter of milliseconds, to provide a seamless user experience.
# 2. **Scalability**: With the increasing amount of text data being generated, fast language models are necessary to process and analyze large volumes of data efficiently. This enables businesses and organizations to scale their language processing capabilities and handle large workloads.
# 3. **Low Latency**: Fast language models minimize latency, which is the time it takes for a model to process and respond to input. Low latency is critical in applications where timely responses are essential, such as in customer service, emergency response systems, or financial trading platforms.
# 4. **Improved User Experience**: Fast language models can significantly improve the user experience by providing quick and accurate responses to user queries. This leads to increased user engagement, satisfaction, and loyalty.
# 5. **Competitive Advantage**: Organizations that leverage fast language models can gain a competitive advantage by responding quickly to customer inquiries, providing timely support, and offering personalized services.
# 6. **Cost Savings**: Fast language models can help reduce costs by minimizing the computational resources required to process language tasks. This leads to lower infrastructure costs, reduced energy consumption, and increased overall efficiency.
# 7. **Enhanced Security**: Fast language models can help detect and respond to security threats, such as phishing attacks or malicious code, in real-time, reducing the risk of data breaches and cyber attacks.
# 8. **Better Decision-Making**: Fast language models can provide timely insights and analytics, enabling businesses and organizations to make data-driven decisions quickly and effectively.
# 9. **Increased Accessibility**: Fast language models can facilitate communication for people with disabilities, such as those who rely on speech-to-text or text-to-speech systems, by providing quick and accurate language processing.
# 10. **Advancements in Research**: Fast language models can accelerate research in NLP and other related fields, such as cognitive science, linguistics, and human-computer interaction, by enabling researchers to test and iterate on their ideas quickly.
#
# To achieve fast language models, researchers and developers employ various techniques, such as:
#
# 1. **Model pruning**: Reducing the size and complexity of language models to improve inference speed.
# 2. **Knowledge distillation**: Transferring knowledge from large, pre-trained models to smaller, more efficient models.
# 3. **Quantization**: Representing model weights and activations using lower-precision data types to reduce computational requirements.
# 4. **Parallelization**: Distributing language processing tasks across multiple processing units, such as GPUs or CPUs, to increase throughput.
# 5. **Hardware acceleration**: Leveraging specialized hardware, such as tensor processing units (TPUs) or graphics processing units (GPUs), to accelerate language processing tasks.
#
# By developing and deploying fast language models, organizations can unlock the full potential of NLP and provide innovative, efficient, and effective language-based services and applications.

# %%
from dotenv import load_dotenv
import langchain
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate

load_dotenv()
GROQ_API_KEY=os.getenv("GROQ_API_KEY")

def initiatellm():
    try:
     llm= ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    api_key=GROQ_API_KEY
)
     return llm
    except Exception as e:
     print(f"Error message:{e.message}")
     return None

# %%
llm=initiatellm()
response=llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is Paris.
